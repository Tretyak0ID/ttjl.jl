# %% [markdown]
# # Usage example

# %%
using Pkg
using ttjl
Pkg.activate("../")
# Out:
# [ Info: Precompiling ttjl [1989a96c-dc04-4193-9e71-0cf1c6a9afa0]
#   Activating project at `~/.julia/dev/ttjl`

# %%
#standart initializations
#1) From CoreCell array
G = CoreCell(undef, 3)
G[1] = rand(1, 4, 3)
G[2] = rand(3, 6, 4)
G[3] = rand(4, 3, 1)
X = tt_tensor(G)

#2) Random TT-tensor
Y = tt_rand([10, 20, 10], [4, 7])
# Out:
# tt_tensor(AbstractArray{<:Number, 3}[[1.1456350392419237 1.1455172952853014 … -0.3925892324003435 0.5285308139481105;;; -0.2028310522798322 1.1965400504423134 … 1.9865017457909735 0.6018062778386553;;; 0.19665489388240218 0.7365574158060243 … 0.07456641919539221 -0.8934210666760325;;; -0.14670063792459312 -0.7936305629369875 … -0.6940346199958267 -0.3135567640575487], [-0.6298882442832034 -0.7057089351702034 … -1.8260452464171706 -1.2449390363238046; -1.476559537233323 -1.7558160280945758 … 0.5401190847584099 -1.0383657474383865; -1.3580041007749706 -1.1403002615482776 … -1.310139855469121 -1.7741237014045919; -0.17504480455783641 -0.5918344005754813 … 0.2916710964437658 -1.7769193836727242;;; -0.6729790754928541 1.4933153497940648 … 0.40870243295083386 0.7536975198057657; 0.3320141586683426 0.6354595310211059 … 0.15171869014134395 -1.5095847657873895; -1.670045314925792 -1.135670324222028 … -1.8187460330995016 1.2583295123952758; 0.21613754848538969 0.30093327507554785 … -0.99183701
# ...

# %%
kron
# Out:
# kron (generic function with 27 methods)
